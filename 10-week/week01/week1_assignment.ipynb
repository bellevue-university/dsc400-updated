# %% [markdown]
# # Part1a: Introduction to Big Data and Python Fundamentals
#
#
# ## Definition and Scope:
# - Big Data encompasses the large-scale collection, processing, and analysis of data that exceeds the capability of traditional databases to manage.
# - Characterized by the three Vs:
#    * **Volume**: The quantity of data generated is massive, often in petabytes or exabytes.
#    * **Velocity**: Data flows at unprecedented speed, necessitating prompt processing.
#    * **Variety**: Data comes in various formats – structured, semi-structured, and unstructured (e.g., text, video, images).
#
# ## Challenges:
# - **Storage**: Storing such large volumes of data efficiently.
# - **Analysis**: Quickly analyzing data to derive actionable insights.
# - **Privacy**: Ensuring the privacy and security of data while using it to gain insights.
# - **Integration**: Combining data from various sources and making it usable.
#
# ## Importance:
# - Big Data analytics helps businesses to understand more about their operations, predict customer behavior, optimize operations, and personalize services.
# - In science and research, it allows for the analysis of complex phenomena which were previously infeasible to study.
#
# ## Technological Foundations:
# - Technologies such as Hadoop and Spark are crucial for processing Big Data. They allow for distributed processing of data across many systems.
#
# ## Python for Data Analysis:
# - Python is preferred for Big Data due to its simplicity and the powerful libraries it supports.
#
# ## Key Python Libraries:
#    * **NumPy**: Supports large, multi-dimensional arrays and matrices, providing a broad range of mathematical functions to operate on these arrays.
#    * **Pandas**: Offers data manipulation and analysis capabilities, ideal for manipulating numerical tables and time series data.
#    * **Matplotlib/Seaborn**: These libraries are used for creating static, animated, and interactive visualizations in Python.
#
# ## Applications:
# - **E-commerce**: Big Data analytics can track user interactions and improve customer service by personalizing experiences.
# - **Healthcare**: Enables predictive analytics for patient care and operational improvements in hospitals.
# - **Finance**: Used for risk analytics, fraud detection, and high-frequency trading strategies.
#
# ## Conclusion:
# - Understanding and utilizing Big Data effectively is crucial for innovation and maintaining competitive advantage in today's data-driven world. Python, with its comprehensive ecosystem, plays a pivotal role in facilitating these processes.
#
# # Part 1b: Data Visualization Techniques
#
# ## Introduction to Data Visualization
# - Data visualization is the practice of converting data from a raw format into a graphical representation such as charts, graphs, and maps.
# - Effective visualization helps to communicate information clearly and efficiently, enhancing the decision-making process by illuminating trends and behaviors that might not be apparent from raw data alone.
#
# ## Importance of Data Visualization
# - **Accessibility:** Makes complex data more comprehensible and accessible to various stakeholders.
# - **Pattern Recognition:** Facilitates the detection of trends, patterns, and outliers, which are crucial for predictive analyses and strategic planning.
# - **Communication:** Aids in communicating findings succinctly in an engaging and informative manner.
#
# ## Key Python Libraries
# - `matplotlib`: A comprehensive library for creating static, animated, and interactive visualizations in Python.
# - `seaborn`: Based on matplotlib, it provides a high-level interface for drawing attractive and informative statistical graphics.
# - `plotly`: An advanced framework for creating interactive visualizations directly in the web browser.
#
# ## Choosing the Right Type of Visualization
# - The selection of visualization types should be dictated by the story you want to tell with your data, whether it’s trends over time with line graphs, comparisons with bar charts, distributions with histograms, or relationships with scatter plots.
#
# ## Ethical Considerations
# - When visualizing data, it is important to maintain accuracy and integrity in the representation of data to avoid misleading users.
#
# ## Legal Considerations
# - Ensure that the data used in visualizations does not infringe on copyright laws or violate privacy policies, especially when dealing with sensitive or proprietary information.

# %% [markdown]
# # Part 2a: Follow Me - Working with pandas on a Larger Dataset

# %%
import numpy as np
import pandas as pd

# %%
# Load the "E-commerce Transactions" Dataset
transactions_df = pd.read_csv('ecommerce.csv')

# %%
# Display the first few rows of the dataset to get an initial understanding of the data structure
print("Initial Data:")
print(transactions_df.head())
# Out:
# Initial Data:
#    TransactionID  UserID  TransactionAmount      TransactionDate  \
# 0              1     861             240.18  2021-01-01 00:00:00
# 1              2    1295              21.52  2021-01-01 01:00:00
# 2              3    1131              53.83  2021-01-01 02:00:00
# 3              4    1096              59.58  2021-01-01 03:00:00
# 4              5    1639              91.38  2021-01-01 04:00:00
#
#   ProductCategory
# 0           Books
# 1     Electronics
# 2     Electronics
# 3            Home
# 4     Electronics

# %% [markdown]
# Data Manipulation in pandas:
# 1. Selecting Specific Columns:
# We often need only a subset of the data to perform analysis. Here, we select two columns, 'TransactionAmount' and 'ProductCategory', to focus on the transaction details.

# %%
print("\nSelected Columns:")
transaction_details = transactions_df[['TransactionAmount', 'ProductCategory']]
print(transaction_details.head())
# Out:
# Selected Columns:
#    TransactionAmount ProductCategory
# 0             240.18           Books
# 1              21.52     Electronics
# 2              53.83     Electronics
# 3              59.58            Home
# 4              91.38     Electronics

# %% [markdown]
# 2. Adding a New Column for Data Categorization:
# Adding new columns based on conditions or calculations is a common task in data manipulation. Below, we categorize transactions into three groups ('Low', 'Medium', 'High') based on the transaction amount.

# %%
print("\nCategorized Transaction Amounts:")
conditions = [
    (transactions_df['TransactionAmount'] < 100),
    (transactions_df['TransactionAmount'] <= 500),
    (transactions_df['TransactionAmount'] > 500)
]
labels = ['Low', 'Medium', 'High']
transactions_df['AmountCategory'] = np.select(conditions, labels)
print(transactions_df.head())
# Out:
# Categorized Transaction Amounts:
#    TransactionID  UserID  TransactionAmount      TransactionDate  \
# 0              1     861             240.18  2021-01-01 00:00:00
# 1              2    1295              21.52  2021-01-01 01:00:00
# 2              3    1131              53.83  2021-01-01 02:00:00
# 3              4    1096              59.58  2021-01-01 03:00:00
# 4              5    1639              91.38  2021-01-01 04:00:00
#
#   ProductCategory AmountCategory
# 0           Books         Medium
# 1     Electronics            Low
# 2     Electronics            Low
# 3            Home            Low
# 4     Electronics            Low

# %% [markdown]
# 3. Filtering Data:
# Identifying high-value transactions is crucial for businesses focusing on revenue optimization. It helps in recognizing customer segments that contribute significantly to sales.

# %%
print("\nHigh-Value Transactions:")
high_value = transactions_df[transactions_df['TransactionAmount'] > 1000]
print(high_value.head())
# Out:
# High-Value Transactions:
# Empty DataFrame
# Columns: [TransactionID, UserID, TransactionAmount, TransactionDate, ProductCategory, AmountCategory]
# Index: []

# %% [markdown]
# 4. Grouping and Aggregating Data:
# Understanding average transaction amounts by product category can inform targeted marketing strategies and product development. This step provides insights into which categories are more popular or lucrative.

# %%
print("\nAverage Transaction Amount by Product Category:")
avg_transaction = transactions_df.groupby('ProductCategory')['TransactionAmount'].mean()
print(avg_transaction)
# Out:
# Average Transaction Amount by Product Category:
# ProductCategory
# Beauty          98.464359
# Books          101.944183
# Clothing        95.859881
# Electronics     99.356891
# Home            98.704538
# Name: TransactionAmount, dtype: float64

# %% [markdown]
# # Part 2a: Follow Me - Creating Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Importing a dataset for demonstration
# For this part, we are using a fictional dataset 'sales_data.csv' that contains sales information over time
sales_data = pd.read_csv('sales_data.csv')

# %%
# Explaining each step in the visualization process with matplotlib
# Here we demonstrate how to plot a histogram of sales amounts
plt.figure(figsize=(10, 6))
plt.hist(sales_data['Sales'], bins=20, color='navy', alpha=0.7)
plt.title('Distribution of Sales')
plt.xlabel('Sales Amount ($)')
plt.ylabel('Number of Transactions')
plt.grid(True)
plt.show()

# %%
# Using seaborn to create a scatter plot
# This plot will show the relationship between the number of customers and sales
sns.set(style="whitegrid")
sns.scatterplot(x='Sales', y='Customers', data=sales_data, s=100)
plt.title('Customer Count vs. Sales')
plt.xlabel('Sales ($)')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Demonstrating an interactive plot with Plotly Express
# Interactive scatter plot to explore sales amount over time
fig = px.scatter(sales_data, x='Date', y='Sales',
                 size='Customers',  # Using 'Customers' as the size of the points
                 title='Interactive Sales Data Exploration')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Part 3: Advanced Data Analysis and Visualization Tasks
#
# In this part, you will engage in an in-depth data analysis and visualization project using the 'Customer Behavior' dataset. This task will challenge you to apply the skills you've learned to address real-world data complications including missing values, inconsistencies, and outliers. You will use various visualization techniques to represent and explore the data insights you uncover.
#
# ## Data Cleaning:
# - Handle missing values and format inconsistencies. Decide whether to impute these values or to drop the rows/columns based on what's needed for your analysis.
# - Identify any inconsistencies or outliers in the dataset that might skew your analysis and address them accordingly.
#
# ## Feature Engineering:
# - Enhance your dataset by creating new features that provide more depth to your analysis. For example, you might aggregate session data to calculate user-level metrics.
#
# ## Advanced Aggregations:
# - Utilize `pandas` functionalities, such as `.groupby()`, to perform sophisticated data aggregations that reveal underlying trends and patterns.
#
# ## Visualization:
# - Create static visualizations using `matplotlib` or `seaborn` to effectively communicate your findings.
# - Employ `plotly` to develop dynamic visualizations that allow users to explore the data interactively.
#
# ## Instructions:
# 1. Load the dataset into a pandas DataFrame from the path provided.
# 2. Conduct the necessary data cleaning and feature engineering.
# 3. Use aggregation and visualization techniques to uncover and represent interesting trends and patterns in the data.
# 4. Compile your steps and insights into the Jupyter notebook and submit it as your completed assignment.

# %%
# Note: Replace 'customer_behavior.csv' with the actual file path.
customer_behavior_df = pd.read_csv('customer_behavior.csv')
